# %%
import pandas as pd

df = pd.read_csv('train.csv')

# %%
df[0:100].plot()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
x = np.array([1,2,3,4])
error = np.linalg.norm(x) # Scalar / euclidean distance
error2 =  np.sqrt((x** 2).sum())

print(error, error2)
# Out:
# 5.477225575051661 5.477225575051661
